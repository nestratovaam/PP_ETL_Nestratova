# %% [markdown]
# Выполнить парсинг веб-страниц с помощью Beautiful Soup и Pandas открытых источников данных:
# Вариант 17.  Новости компаний и новая информация по акциям — https://smart-lab.ru/news/

# %%
from bs4 import BeautifulSoup as bso
import requests as reqs
import pandas as pd
# Out:
# /Users/alenanestratova/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# Отправление запроса на получение данных и присваивание ответ переменной.
source = reqs.get("https://smart-lab.ru/news/")

# %%
print(f"Content type: \n\t {source.headers['content-type']}")
# Out:
# Content type:
# 	 text/html; charset=utf-8

# %%
print(source)
# Out:
# <Response [200]>

# %%
mysoup = bso(source.text, 'html.parser')

# %%
print(mysoup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ru">
#  <head>
#   <!-- Global Site Tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-16537214-3">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
# 	function gtag(){dataLayer.push(arguments);}
# 	gtag('js', new Date());
# 	gtag('config', 'UA-16537214-3', {
# 			'custom_map': {
# 				'dimension1' : 'user_registred',
# 				'dimension2' : 'content_owner'
#
# 			},
#
# 			'user_registred': 'No',
# 			'content_owner': 'No'	});
#   </script>
#   <meta content="no" name="push-subscribes"/>
#   <title>
#    Новости компаний и новости по акциям
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type">
#    <link href="/manifest.json" rel="manifest"/>
#    <meta content="Все новости по компаниям, которые торгуются на Московской бирже. Причины роста и падения акций. Объяснение новостей экспертами." name="DESCRIPTION"/>
#    <meta content="новости по компаниям, биржевые новости, лента новостей, аналитика по акциям" name="KEYWORDS"/>
#    <meta content="IE=9" http-equiv="X-UA-Compatible"/>
#    <meta content="69df339e9279f161" name="yandex-verification"/>
#    <meta content="6abfc0aaab555b05" name="yandex-verification"/>
#    <meta content="d7fe082f235489d7debbb5709092a42f" name="pmail-verification"/>
#    <meta content="17fde70f-5d0a-4de9-809e-a9f5334ce8dd" name="PartnerFinam"/>
#    <meta content="https://smart-lab.ru/templates/skin/smart-lab-x3/images/og/sm-og1.jpg" property="vk:image"/>
#    <link href="/templates/cache/smart-lab-x3/5dfeb84f2d9195858bd07b69a9876668.css?4579" rel="stylesheet" type="text/css">
#     <!--[if IE]><link rel='stylesheet' type='text/css' href='/templates/skin/smart-lab-x3/css/ie.css?v=1?4579' /><![endif]-->
#     <!--[if IE 6]><link rel='stylesheet' type='text/css' href='/templates/skin/smart-lab-x3/css/ie6.css?v=1?4579' /><![endif]-->
#     <!--[if gte IE 7]><link rel='stylesheet' type='text/css' href='/templates/skin/smart-lab-x3/css/ie7.css?v=1?4579' /><![endif]-->
#     <!--[if gt IE 6]><link rel='stylesheet' type='text/css' href='/templates/skin/smart-lab-x3/css/simple_comments.css?4579' /><![endif]-->
#     <!--[if lt IE 8]><link rel='stylesheet' type='text/css' href='/plugins/trade/templates/skin/default/css/hook.console.ltie8.css?4579' /><![endif]-->
#     <!-- theme_css_begin -->
#     <!-- theme_css_end -->
#     <link href="/templates/skin/smart-lab-x3/images/favicon.ico" rel="shortcut icon"/>
#     <link href="/search/opensearch/" rel="search" title="sMart-lab.ru" type="application/opensearchdescription+xml"/>
#     <link href="https://smart-lab.ru/news/" rel="canonical"/>
#     <link href="/news/rss/" rel="alternate" title="RSS лента новостей акций на sMart-lab.ru" type="application/rss+xml"/>
#     <script type="text/javascript">
#      var DIR_WEB_ROOT = 'https://smart-lab.ru';
# 		var DIR_STATIC_SKIN = '/templates/skin/smart-lab-x3';
# 		var REV = 4579;
# 		var TINYMCE_LANG = 'ru';
# 		var LIVESTREET_SECURITY_KEY = 'fd8ad318e9844750ee0c6c9566c0f6ff';
#
#
# 		var tinyMCE = false;
#     </script>
#     <script src="/templates/cache/smart-lab-x3/ab60c0143e11b43e34b5112d376f4e54.js?4579" type="text/javascript">
#     </script>
#     <!--Скрипт ADFOX-->
#     <script async="" src="https://yandex.ru/ads/system/header-bidding.js">
#     </script>
#     <script async="" src="/templates/skin/smart-lab-x3/js/adfox_hb_desktop.js?4579">
#     </script>
#     <script>
#      window.yaContextCb = window.yaContextCb || []
#     </script>
#     <script async="" src="https://yandex.ru/ads/system/context.js">
#     </script>
#     <script async="" src="https://content.adriver.ru/AdRiverFPS.js">
#     </script>
#     <script type="text/javascript">
#      (function(a,e,f,g,b,c,d){a[b]||(a.FintezaCoreObject=b,a[b]=a[b]||function(){(a[b].q=a[b].q||[]).push(arguments)},a[b].l=1*new Date,c=e.createElement(f),d=e.getElementsByTagName(f)[0],c.async=!0,c.defer=!0,c.src=g,d&&d.parentNode&&d.parentNode.insertBefore(c,d))})
# 	(window,document,"script","https://content.mql5.com/core.js","fz");
# 	fz("register","website","ddhmfkdhagrouzesxgjyvzdhtcwwubymll");
#     </script>
#    </link>
#   </meta>
#  </head>
#  <body>
#   <!-- verify-admitad: "cd8cb15f31" -->
#   <div id="cover" style="display:none;">
#   </div>
#   <!-- user_warning_block -->
#   <div id="container">
#    <!-- Header -->
#    <div style="display: none;">
#     <div class="login-popup" id="login-form">
#      <div class="login-popup-top">
#       <a class="close-block" href="#" onclick="return false;">
#       </a>
#      </div>
#      <div class="content">
#       <form action="/login/" method="POST">
#        <input name="security_ls_key" type="hidden" value="fd8ad318e9844750ee0c6c9566c0f6ff"/>
#        <h3>
#         Авторизация
#        </h3>
#        <div class="lite-note">
#         <a href="/registration/">
#          Зарегистрироваться
#         </a>
#         <label>
#          Логин или эл. почта
#         </label>
#        </div>
#        <p>
#         <input class="input-text" id="login-input" name="login" tabindex="1" type="text"/>
#        </p>
#        <div class="lite-note">
#         <a href="/login/reminder/" tabindex="-1">
#          Напомнить пароль
#         </a>
#         <label>
#          Пароль
#         </label>
#        </div>
#        <p>
#         <input class="input-text" name="password" tabindex="2" type="password"/>
#        </p>
#        <div class="lite-note">
#         <button onfocus="blur()" type="submit">
#          <span>
#           <em>
#            Войти
#           </em>
#          </span>
#         </button>
#         <label class="input-checkbox">
#          <input checked="" name="remember" tabindex="3" type="checkbox"/>
#          Запомнить меня
#         </label>
#        </div>
#        <input name="submit_login" type="hidden"/>
#       </form>
#      </div>
#      <div class="login-popup-bottom">
#      </div>
#     </div>
#    </div>
#    <div id="header">
#     <div class="toggle">
#      <a class="toggle_fz">
#       <img alt="Изменить размер" class="toggle_fz__img" src="/templates/skin/smart-lab-x3/images/font_download-24px.svg?4579"/>
#      </a>
#      <div class="theme_switch_btn">
#       <a theme="black" title="Переключиться на черную тему">
#       </a>
#       <a theme="white" title="Переключиться на белую тему">
#       </a>
#       <a theme="fullblack" title="Переключиться на полностью черную тему">
#       </a>
#      </div>
#     </div>
#     <div class="center">
#      <div class="profile guest">
#       <a href="/login/">
#        <img class="mart_login" src="/templates/skin/smart-lab-x3/images/login_btn.svg?4579"/>
#       </a>
#      </div>
#      <div>
#       <div class="h1">
#        <a href="/">
#         SMART-LAB
#        </a>
#        <div>
#         Мы делаем деньги на бирже
#        </div>
#       </div>
#       <a class="transfer-btn-header-mobile" href="https://smart-lab.ru/mobile/allnews/">
#        Новый дизайн
#       </a>
#      </div>
#     </div>
#    </div>
#    <!-- /Header -->
#    <div style="text-align: center;">
#     <!--AdFox START-->
#     <!--timmartynov-->
#     <!--Площадка: smart-lab.ru / * / *-->
#     <!--Тип баннера: Первый баннер смартлаб-->
#     <!--Расположение: <верх страницы>-->
#     <div id="adfox_151594297503669505">
#     </div>
#     <script type="text/javascript">
#      window.yaContextCb.push(()=>{
# 				Ya.adfoxCode.create({
# 					ownerId: 264040,
# 					containerId: 'adfox_151594297503669505',
# 					params: {
# 						pp: 'g',
# 						ps: 'cqfw',
# 						p2: 'fuct',
# 						puid1: ''
# 					},
# 				});
# 			});
#     </script>
#    </div>
#    <div class="" id="wrapper">
#     <div class="console_box">
#      <div class="console">
#       <div class="commandline">
#        <input type="text"/>
#       </div>
#      </div>
#      <div class="undermenu" id="umline">
#       <ul>
#        <li class="more" submenu="undermenu_more_main">
#         <a aria-label="Главное меню сайта" id="main_menu" title="Главное меню - карта сайта">
#          <i>
#          </i>
#         </a>
#        </li>
#        <li class="more" submenu="undermenu_more_quotes">
#         <a aria-label="Меню котировок онлайн" id="quotes_menu" title="Котировки онлайн">
#          <i>
#          </i>
#          Котировки
#         </a>
#        </li>
#        <li>
#         <a href="/forum/" title='Форум акций&lt;br /&gt;+16 новых постов за день по теме "акции"'>
#          Акции
#          <span>
#           +16
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="/bonds/" title='Форум по облигациям&lt;br /&gt;+7 новых постов за день по теме "облигации"'>
#          Облигации
#          <span>
#           +7
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="/brokers-rating/" title='Рейтинг брокеров&lt;br /&gt;+1 новый пост за день по теме "брокеры"'>
#          Брокеры
#          <span>
#           +1
#          </span>
#         </a>
#        </li>
#        <li class="more" submenu="undermenu_more_other">
#         <a id="other_menu">
#          Другие
#          <span>
#           +10
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="undermenu_more_main clickmenu" id="undermenu_more_main">
#       <div class="menu_columns">
#        <div class="menu_column">
#         <div class="menu_column__item">
#          <h4 class="menu_column__title">
#           Ленты
#          </h4>
#          <ul class="menu_column__list">
#           <li>
#            <a href="/allpremium/">
#             <img alt="PREMIUM" loading="lazy" onclick="window.fz('track', 'old main_menu mozgovik click')" src="/templates/skin/smart-lab-x3/images/premium.svg?4579"/>
#             <span>
#              PREMIUM
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="menu_bg__orange" href="/allblog/">
#             <img alt="Все блоги" loading="lazy" src="/templates/skin/smart-lab-x3/images/main-menu/all-blog.svg?4579">
#              <span>
#               Все блоги
#              </span>
#             </img>
#            </a>
#           </li>
#           <li>
#            <a class="menu_bg__green" href="/chat/">
#             <img alt="Чат" loading="lazy" src="/templates/skin/smart-lab-x3/images/main-menu/chat.svg?4579"/>
#             <span>
#              Чат
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="menu_bg__green" href="/news/">
#             <img alt="Новости" loading="lazy" src="/templates/skin/smart-lab-x3/images/main-menu/news.svg?4579"/>
#             <span>
#              Новости
#             </span>
#            </a>
#           </li>
#           <li>
#            <a href="/flow/">
#             Поток
#            </a>
#           </li>
#           <li>
#            <a href="/blog/tradesignals/">
#             Сигналы
#            </a>
#           </li>
#           <li>
#            <a href="/forums/">
#             Форумы
#            </a>
#           </li>
#           <li>
#            <a class="menu_bg__green" href="/top/">
#             <img alt="Топ 24" loading="lazy" src="/templates/skin/smart-lab-x3/images/main-menu/top24.svg?4579"/>
#             <span>
#              Топ 24
#             </span>
#            </a>
#           </li>
#           <li>
#            <a href="/vopros/">
#             Вопросы
#            </a>
#           </li>
#           <li>
#            <a href="/smartlab-tv/">
#             Видео
#            </a>
#           </li>
#           <li>
#            <a href="/blog/offtop/" rel="nofollow">
#             Оффтоп
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <!-- second column -->
#        <div class="menu_column">
#         <div class="menu_column__item">
#          <h4 class="menu_column__title">
#           Форумы
#          </h4>
#          <ul class="menu_column__list">
#           <li>
#            <a class="menu_bg__orange" href="/forum/">
#             Форум акций
#            </a>
#           </li>
#           <li>
#            <a href="/trading/">
#             Общий
#            </a>
#           </li>
#           <li>
#            <a href="/bonds/">
#             Облигации
#            </a>
#           </li>
#           <li>
#            <a href="/algotrading/">
#             Торговые роботы
#            </a>
#           </li>
#           <li>
#            <a href="/options/">
#             Опционы
#            </a>
#           </li>
#           <li>
#            <a href="/forex/">
#             Forex
#            </a>
#           </li>
#           <li>
#            <a href="/banki/">
#             Банки
#            </a>
#           </li>
#           <li>
#            <a href="/brokers-rating/">
#             Брокеры
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="menu_column__item">
#          <h4 class="menu_column__title">
#           Участники
#          </h4>
#          <ul class="menu_column__list">
#           <li>
#            <a class="menu_bg__green" href="/people/">
#             <img alt="Люди" loading="lazy" src="/templates/skin/smart-lab-x3/images/main-menu/people.svg?4579"/>
#             <span>
#              Люди
#             </span>
#            </a>
#           </li>
#           <li>
#            <a href="/mobile/company/">
#             <img alt="Компании" loading="lazy" src="/templates/skin/smart-lab-x3/images/main-menu/companies.svg?4579"/>
#             <span>
#              Компании
#             </span>
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <!-- third column -->
#        <div class="menu_column">
#         <div class="menu_column__item">
#          <h4 class="menu_column__title">
#           Котировки
#          </h4>
#          <ul class="menu_column__list">
#           <li>
#            <a class="menu_bg__orange" href="/q/shares/">
#             <img alt="Котировки акций" loading="lazy" src="/templates/skin/smart-lab-x3/images/main-menu/quotes.svg?4579"/>
#             <span>
#              Котировки акций
#             </span>
#            </a>
#           </li>
#           <li>
#            <a href="/q/ofz/">
#             <img alt="Облигации федерального займа" loading="lazy" src="/templates/skin/smart-lab-x3/images/main-menu/ofz.svg?4579"/>
#             <span>
#              ОФЗ
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="menu_bg__green" href="/q/map/">
#             Карта рынка
#            </a>
#           </li>
#           <li>
#            <a href="/q/futures/">
#             Фьючерсы
#            </a>
#           </li>
#           <li>
#            <a href="/q/world-quotes/">
#             Мир/FX/Сырье/Крипта
#            </a>
#           </li>
#           <li>
#            <a href="/g/">
#             <img alt="Графики онлайн" loading="lazy" src="/templates/skin/smart-lab-x3/images/main-menu/charts.svg?4579"/>
#             <span>
#              Графики онлайн
#             </span>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="menu_column__item">
#          <h4 class="menu_column__title">
#           Акции
#          </h4>
#          <ul class="menu_column__list">
#           <li>
#            <a class="menu_bg__orange" href="/dividends/">
#             <img alt="Дивиденды" loading="lazy" src="/templates/skin/smart-lab-x3/images/main-menu/dividends.svg?4579"/>
#             <span>
#              Дивиденды
#             </span>
#            </a>
#           </li>
#           <li>
#            <a href="/q/shares_fundamental3/">
#             <img alt="Отчеты РСБУ/МСФО" loading="lazy" src="/templates/skin/smart-lab-x3/images/main-menu/reports.svg?4579"/>
#             <span>
#              Отчеты РСБУ/МСФО
#             </span>
#            </a>
#            <li>
#             <a href="/q/shares_fundamental/">
#              <img alt="Фундам. анализ" loading="lazy" src="/templates/skin/smart-lab-x3/images/main-menu/fundamental.svg?4579"/>
#              <span>
#               Фундам. анализ
#              </span>
#             </a>
#            </li>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <!-- four column -->
#        <div class="menu_column">
#         <div class="menu_column__item">
#          <h4 class="menu_column__title">
#           Календарь
#          </h4>
#          <ul class="menu_column__list">
#           <li>
#            <a class="menu_bg__green" href="/calendar/stocks/">
#             <img alt="Акции" loading="lazy" src="/templates/skin/smart-lab-x3/images/main-menu/shares.svg?4579"/>
#             <span>
#              Акции
#             </span>
#            </a>
#           </li>
#           <li>
#            <a href="/calendar/economic/">
#             Экономика
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="menu_column__item">
#          <h4 class="menu_column__title">
#           Информация
#          </h4>
#          <ul class="menu_column__list">
#           <li>
#            <a href="/finansoviy-slovar/">
#             <img alt="Энциклопедия" loading="lazy" src="/templates/skin/smart-lab-x3/images/main-menu/wiki.svg?4579"/>
#             <span>
#              Энциклопедия
#             </span>
#            </a>
#           </li>
#           <li>
#            <a href="/tradingreads/">
#             Лучшие статьи
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="menu_column__item">
#          <h4 class="menu_column__title">
#           Книги
#          </h4>
#          <ul class="menu_column__list">
#           <li>
#            <a href="/books/">
#             <img alt="Каталог книг" loading="lazy" src="/templates/skin/smart-lab-x3/images/main-menu/books-catalog.svg?4579"/>
#             <span>
#              Каталог книг
#             </span>
#            </a>
#           </li>
#           <li>
#            <a href="/books/top/">
#             100 лучших книг
#            </a>
#           </li>
#           <li>
#            <a href="/blog/reviews/">
#             Книжные рецензии
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="undermenu_more clickmenu" id="undermenu_more_quotes">
#       <ul>
#        <li>
#         <a href="/q/shares/" title="Котировки акций">
#          Российские акции
#          <i>
#           - Московская Биржа
#          </i>
#         </a>
#        </li>
#        <li>
#         <a href="/q/moex-otc/" title="Котировки акций">
#          Внемаркет
#          <i>
#           - Московская Биржа
#          </i>
#         </a>
#        </li>
#        <li>
#         <a href="/q/currencies/" title="Котировки валют Московская Биржа">
#          Валютный рынок
#          <i>
#           - Московская Биржа
#          </i>
#         </a>
#        </li>
#        <li>
#         <a href="/q/bonds/" title="Котировки облигаций">
#          Корпоративные облигации
#          <i>
#           - Московская Биржа
#          </i>
#         </a>
#        </li>
#        <li>
#         <a href="/q/ofz/" title="Котировки ОФЗ">
#          ОФЗ
#          <i>
#           - Московская Биржа
#          </i>
#         </a>
#        </li>
#        <li>
#         <a href="/q/futures/">
#          Фьючерсы
#         </a>
#        </li>
#        <li>
#         <a href="/q/world-quotes/">
#          Фондовые индексы, сырьевые рынки, FOREX
#         </a>
#        </li>
#        <li>
#         <a href="/q/usa/" title="Котировки американских акций">
#          Американские акции
#          <i>
#           - Биржи США
#          </i>
#         </a>
#        </li>
#        <li>
#         <a href="/q/world-stocks/" title="Котировки иностранных акций">
#          Мировые акции
#          <i>
#           - Иностранные Биржи
#          </i>
#         </a>
#        </li>
#        <li>
#         <a href="/q/etf/" title="Котировки БПИФ и ETF">
#          Биржевые ПИФы и ETF
#          <i>
#           - Московская Биржа
#          </i>
#         </a>
#        </li>
#        <li>
#         <a href="/q/usa-stocks-moex/">
#          Американские акции
#          <i>
#           - Московская Биржа
#          </i>
#         </a>
#        </li>
#        <li>
#         <a href="/q/pif/" title="Котировки ПИФов Московская Биржа">
#          ПИФы
#          <i>
#           - Московская Биржа
#          </i>
#         </a>
#        </li>
#        <li>
#         <a href="/q/eurobonds/" title="Котировки еврооблигаций">
#          Еврооблигации
#          <i>
#           - Московская Биржа
#          </i>
#         </a>
#        </li>
#        <li>
#         <a href="/q/index_stocks/" title="Котировки индексов Московской Биржи">
#          Индексы Российских Акций
#         </a>
#        </li>
#        <li>
#         <a href="/q/repo-s-ck/" title="ставки РЕПО с ЦК">
#          РЕПО с ЦК
#         </a>
#        </li>
#        <li>
#         <a href="/q/index_repo/" title="Индексы РЕПО">
#          Индексы РЕПО
#         </a>
#        </li>
#        <li>
#         <a href="/q/index_bonds/" title="Индексы облигаций">
#          Индексы облигаций
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="undermenu_more clickmenu" id="undermenu_more_other" style="left: 437.5px; display: none;">
#       <ul>
#        <li>
#         <a href="/trading/" title="Свободный форум">
#          Общий форум
#         </a>
#        </li>
#        <li>
#         <a href="/forex/" title='Форум по форексу&lt;br /&gt;+3 новых поста за день по теме "Forex"'>
#          Forex
#          <span>
#           +3
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="/options/" title="Форум по опционам">
#          Опционы
#         </a>
#        </li>
#        <li>
#         <a href="/algotrading/" title='Форум по алготрейдингу&lt;br /&gt;+1 новый пост за день по теме "алготрейдинг"'>
#          Алго
#          <span>
#           +1
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="/trading-software/" title='Софт для трейдинга&lt;br /&gt;+1 новый пост за день по теме "трейдерский софт"'>
#          Софт
#          <span>
#           +1
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="/crypto/" title='Форум по криптовалютам&lt;br /&gt;+5 новых постов за день по теме "криптовалюты"'>
#          Криптовалюта
#          <span>
#           +5
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="/banki/" title="Форум по банкам">
#          Банки
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <script type="text/javascript">
#      (function($)
# 	{
# 		var console_params = {
#
# 			commands : console_commands,
# 			aliases : console_aliases,
# 		};
#
# 		if (typeof(CURRENT_USER_LOGIN) !== 'undefined')	console_params['login'] = CURRENT_USER_LOGIN;
# 		$('.console').smart_console(console_params);
#
# 		function hideClickMenu(e)
# 		{
# 			if (e.target.nodeName == 'A')
# 			{
# 				$('body').off('click', hideClickMenu);
# 				$('.clickmenu').hide();
# 				$('.undermenu .more.open').removeClass('open');
# 				return;
# 			}
#
# 			var cm = $(e.target);
# 			if (!cm.hasClass('clickmenu') && !cm.hasClass('popupmenu')) cm = cm.parents('.clickmenu, .popupmenu');
# 			if (!cm.length)
# 			{
# 				$('body').off('click', hideClickMenu);
# 				$('.clickmenu').hide();
# 				$('.undermenu .more.open').removeClass('open');
# 			}
# 		}
#
# 		$('.undermenu').find('.more').find('a,span').on('click', function(e)
# 		{
# 			e.preventDefault();
# 			var menu = $(e.target).parents('li').attr('submenu');
# 			var bOpened = ($('#'+menu).css('display') == 'block');
#
# 			$('.clickmenu').hide();
# 			$('.undermenu .more.open').removeClass('open');
#
# 			if (!bOpened)
# 			{
# 				var menuitem = $($(e.target).parents('li').get(0));
# 				var offset = menuitem.offset();
#
# 				$('#'+menu).css('left', offset.left + 'px');
# 				$('#'+menu).show();
#
# 				menuitem.addClass('open');
#
# 				e.stopPropagation();
# 				$('body').on('click', hideClickMenu);
# 			}
# 		});
#
#
# 		$('.undermenu_more_main').on('mouseover', '.popupmenu', function(e)
# 		{
# 			var menuItem = $(e.target).parents('.submenu');
# 			if (!menuItem.hasClass('selected'))
# 			{
# 				menuItem.addClass('selected');
# 				var subMenu = $(e.target);
# 				if (!subMenu.hasClass('.popupmenu')) subMenu = subMenu.parents('.popupmenu');
#
# 				subMenu.on('mouseleave', function(e)
# 				{
# 					subMenu.off('mouseleave');
# 					menuItem.removeClass('selected');
# 				});
# 			}
# 		});
#
# 		$('#umline a[title],#umline span[title], #undermenu_more_other a[title],#undermenu_more_other span[title]').jBox('Tooltip', {
# 			addClass: 'q-tooltip',
# 			maxWidth: '300px'
# 		});
#
# 	})(jQuery);
#     </script>
#     <!-- Content -->
#     <div class="wide" id="content_box">
#      <div class="content_desc">
#       <p class="left">
#        <a href="/news/rss/">
#         rss
#        </a>
#       </p>
#       <p>
#        Новости акций
#       </p>
#      </div>
#      <div class="" id="content">
#       <style>
#        .allbloglist *, .panel *{font-weight: normal;}.banner-img-tg{display: block;max-width: 100%;height: auto;vertical-align: middle;margin-right: auto;margin-left: auto;}
#       </style>
#       <div>
#        <a href="https://t.me/newssmartlab" id="allnews_banner" target="_blank">
#         <img class="banner-img-tg" src="/templates/skin/smart-lab-x3/images/banners/news21.png?4579"/>
#        </a>
#       </div>
#       <div class="allblog_panel">
#        <div class="undermenu">
#         <ul>
#          <li>
#           <a href="/allblog/">
#            Все блоги
#           </a>
#          </li>
#          <li>
#           <a href="/allsignals/">
#            Торговые сигналы
#           </a>
#          </li>
#          <li class="active">
#           <a class="thin" href="/news/">
#            Новости акций
#           </a>
#          </li>
#          <li>
#           <a class="thin" href="/disclosure/">
#            Раскрытие информации
#           </a>
#          </li>
#          <li>
#           <a class="thin icon" href="/allpremium/" onclick="window.fz('track', 'old allblogs_tabs mozgovik click')">
#            <img src="/templates/skin/smart-lab-x3/images/premium.svg?4579">
#             PREMIUM
#            </img>
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="panel">
#         <span class="sort_btn" title="Выбрать сортировку">
#          <div class="chat_more__wrapper blog_more__wrapper">
#           <a class="chat_more__btn">
#            <img alt="Еще" src="/templates/skin/smart-lab-x3/images/topic/download.png?4579"/>
#            ⌚ по дате
#           </a>
#           <div class="chat_more__overlay">
#           </div>
#           <ul class="chat_more__list">
#            <li class="chat_more__item">
#             <a href="/news/list/order_by_favourite/desc/">
#              <span>
#               ⭐️
#              </span>
#              <span>
#               по пользе
#              </span>
#             </a>
#            </li>
#            <li class="chat_more__item">
#             <a href="/news/list/order_by_rating/desc/">
#              <span>
#               ❤️
#              </span>
#              <span>
#               по плюсам
#              </span>
#             </a>
#            </li>
#            <li class="chat_more__item">
#             <a href="/news/list/order_by_comment/desc/">
#              <span>
#               🔥
#              </span>
#              <span>
#               по комментам
#              </span>
#             </a>
#            </li>
#            <li class="chat_more__item">
#             <a href="/news/list/">
#              <span>
#               ⌚
#              </span>
#              <span>
#               по дате
#              </span>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </span>
#         <span class="refres_btn" field="bRefreshAllnews" title="Включить автообновление 1 раз в минуту">
#         </span>
#         <input autocomplete="off" id="all_date" name="date" placeholder="Выбрать дату" route="/news/" title="Посмотреть за выбраную дату" type="text" value="">
#          <div id="allnews_search">
#           <form action="/search/topics/" method="GET">
#            <input name="blog" type="hidden" value="news"/>
#            <input id="blog-search" name="q" placeholder="Поиск новостей" type="search"/>
#           </form>
#          </div>
#         </input>
#        </div>
#       </div>
#       <div class="topic allbloglist">
#        <h1>
#         Новости компаний и новости по акциям
#        </h1>
#        <h3 class="feed title bluid_45660">
#         <div class="rating">
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993266.php" title="Прогноз финансовых результатов Аэрофлота за 4 квартал 2023 года - СберИнвестиции">
#           Прогноз финансовых результатов Аэрофлота за 4 квартал 2023 года - СберИнвестиции
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_45660">
#         <div class="rating">
#          <div class="r">
#           +1
#          </div>
#          <div class="c">
#           (1)
#          </div>
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993259.php" title="Brent в марте может нацелиться на $85 за баррель - СберИнвестиции">
#           Brent в марте может нацелиться на $85 за баррель - СберИнвестиции
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_45660">
#         <div class="rating">
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993254.php" title="Совет директоров Распадской принял решение не рекомендовать ГОСА выплату дивидендов за 2023 год - Синара">
#           Совет директоров Распадской принял решение не рекомендовать ГОСА выплату дивидендов за 2023 год - Синара
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_45660">
#         <div class="rating">
#          <div class="c">
#           (0) ★2
#          </div>
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993242.php" title="Топ-акции с наибольшей потенциальной доходностью по выплатам на рынке РФ - Промсвязьбанк">
#           Топ-акции с наибольшей потенциальной доходностью по выплатам на рынке РФ - Промсвязьбанк
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_30271">
#         <div class="rating">
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993241.php" title="Нижнекамскшина РСБУ 2023г: выручка 11,1 млрд руб (+15,8% г/г), чистая прибыль 233,3 млн руб (годом ранее 953 млн руб)">
#           Нижнекамскшина РСБУ 2023г: выручка 11,1 млрд руб (+15,8% г/г), чистая прибыль 233,3 млн руб (годом ранее 953 млн руб)
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_30271">
#         <div class="rating">
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993227.php" title="Микрофинансовые организации выдали более 1 трлн руб за 2023г — Банк России">
#           Микрофинансовые организации выдали более 1 трлн руб за 2023г — Банк России
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_30271">
#         <div class="rating">
#          <div class="r">
#           +4
#          </div>
#          <div class="c">
#           (0) ★1
#          </div>
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993215.php" title="ГК Медси (входит в АФК Система) РСБУ 2023г: выручка 41,65 млрд руб (+15,7% г/г), чистая прибыль 1,23 млрд руб (годом ранее 1,27 млрд руб)">
#           ГК Медси (входит в АФК Система) РСБУ 2023г: выручка 41,65 млрд руб (+15,7% г/г), чистая прибыль 1,23 млрд руб (годом ранее 1,27 млрд руб)
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_30271">
#         <div class="rating">
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993200.php" title="Роснефть начала процесс продажи активов в Германии — Reuters со ссылкой на Минэкономики Германии">
#           Роснефть начала процесс продажи активов в Германии — Reuters со ссылкой на Минэкономики Германии
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_30271">
#         <div class="rating">
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993196.php" title="Канада наложила дополнительный запрет на импорт российских алмазов — МИД страны">
#           Канада наложила дополнительный запрет на импорт российских алмазов — МИД страны
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_30271">
#         <div class="rating">
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993188.php" title="Отзывы банковских лицензий в начале года не означают начало новой зачистки сектора, проблемы точечные; в санации Киви-банка нет необходимости — первый зампред ЦБ РФ">
#           Отзывы банковских лицензий в начале года не означают начало новой зачистки сектора, проблемы точечные; в санации Киви-банка нет необходимости — первый зампред ЦБ РФ
#          </a>
#         </div>
#        </h3>
#        <div style="min-height: 250px; font-size: 0;">
#         <div style="display: inline-block; width: 50%; vertical-align: top;">
#          <!--AdFox START-->
#          <!--MarTi-->
#          <!--Площадка: smart-lab.ru / * / *-->
#          <!--Тип баннера: Кубики-->
#          <!--Расположение: <середина страницы>-->
#          <div id="adfox_mid1">
#          </div>
#          <script>
#           window.yaContextCb.push(()=>{
# 						Ya.adfoxCode.create({
# 							ownerId: 254948,
# 							containerId: 'adfox_mid1',
# 							params: {
# 								pp: 'h',
# 								ps: 'cymb',
# 								p2: 'ganf',
# 								puid1: ''
# 							},
# 						});
# 					});
#          </script>
#         </div>
#         <div style="display: inline-block; width: 50%; vertical-align: top;">
#          <!--AdFox START-->
#          <!--MarTi-->
#          <!--Площадка: smart-lab.ru / * / *-->
#          <!--Тип баннера: Кубики-->
#          <!--Расположение: <середина страницы>-->
#          <div id="adfox_mid2">
#          </div>
#          <script>
#           window.yaContextCb.push(()=>{
# 						Ya.adfoxCode.create({
# 							ownerId: 254948,
# 							containerId: 'adfox_mid2',
# 							params: {
# 								pp: 'h',
# 								ps: 'cymb',
# 								p2: 'ganf',
# 								puid1: ''
# 							},
# 						});
# 					});
#          </script>
#         </div>
#        </div>
#        <h3 class="feed title bluid_30271">
#         <div class="rating">
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993187.php" title="📈Акции Яндекса сегодня +4%, предположительно на заявлении главы ВТБ Андрея Костина о том, что банк продолжает держать пакет акции компании в расчете на рост их стоимости">
#           📈Акции Яндекса сегодня +4%, предположительно на заявлении главы ВТБ Андрея Костина о том, что банк продолжает держать пакет акции компании в расчете на рост их стоимости
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_30271">
#         <div class="rating">
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993177.php" title='Глава ВТБ подвел итоги стратегической недели банка: "Новая 3-хлетняя стратегия банка соответствует задачам, которые стоят перед страной"'>
#           Глава ВТБ подвел итоги стратегической недели банка: "Новая 3-хлетняя стратегия банка соответствует задачам, которые стоят перед страной"
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_30271">
#         <div class="rating">
#          <div class="c">
#           (2)
#          </div>
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993162.php" title="ВТБ РСБУ 2023г: чистая прибыль 223,4 млрд руб (годом ранее убыток 756,7 млрд руб)">
#           ВТБ РСБУ 2023г: чистая прибыль 223,4 млрд руб (годом ранее убыток 756,7 млрд руб)
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_77005">
#         <div class="rating">
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993157.php" title="🔎Мосэнерго Отчет РСБУ">
#           🔎Мосэнерго Отчет РСБУ
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_45660">
#         <div class="rating">
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993153.php" title="Продление программы семейной ипотеки выгодно Самолету - Газпромбанк Инвестиции">
#           Продление программы семейной ипотеки выгодно Самолету - Газпромбанк Инвестиции
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_57203">
#         <div class="rating">
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993152.php" title="Россия с 6 марта понизит экспортную пошлину на пшеницу до 3 575,4 рублей за тонну">
#           Россия с 6 марта понизит экспортную пошлину на пшеницу до 3 575,4 рублей за тонну
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_30271">
#         <div class="rating">
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993151.php" title="Российские авиакомпании лишились почти всех контрактов с ООН — РБК">
#           Российские авиакомпании лишились почти всех контрактов с ООН — РБК
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_57203">
#         <div class="rating">
#          <div class="r">
#           +4
#          </div>
#          <div class="c">
#           (2)
#          </div>
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993142.php" title="BlackRock снизила свою долю в Polymetal">
#           BlackRock снизила свою долю в Polymetal
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_30271">
#         <div class="rating">
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993141.php" title="Мосэнерго РСБУ 2023г: выручка 247,1 млрд руб (+8,9% г/г), чистая прибыль 19,26 млрд руб (-7,1% г/г)">
#           Мосэнерго РСБУ 2023г: выручка 247,1 млрд руб (+8,9% г/г), чистая прибыль 19,26 млрд руб (-7,1% г/г)
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_30271">
#         <div class="rating">
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993139.php" title="ЦБ в 2024г расширит список системно значимых кредитных организаций — зампред Ольга Полякова">
#           ЦБ в 2024г расширит список системно значимых кредитных организаций — зампред Ольга Полякова
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_45660">
#         <div class="rating">
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993135.php" title="Рубль спотыкается о негативные ожидания - Росбанк">
#           Рубль спотыкается о негативные ожидания - Росбанк
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_57203">
#         <div class="rating">
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993132.php" title="Россия впервые использует ценовой минимум для защиты государственных доходов от санкций — Bloomberg">
#           Россия впервые использует ценовой минимум для защиты государственных доходов от санкций — Bloomberg
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_30271">
#         <div class="rating">
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993119.php" title="Генерацию в Сибири построят ТГК-14 и структура Иркутскэнерго, но их заявки не покрыли весь дефицит мощности в регионе — Интерфакс">
#           Генерацию в Сибири построят ТГК-14 и структура Иркутскэнерго, но их заявки не покрыли весь дефицит мощности в регионе — Интерфакс
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_77005">
#         <div class="rating">
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993112.php" title="🔶IR Юнипро: Юнипро публикует результаты по РСБУ за 2023 год">
#           🔶IR Юнипро: Юнипро публикует результаты по РСБУ за 2023 год
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_30271">
#         <div class="rating">
#          <div class="r">
#           +12
#          </div>
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993111.php" title="Юнипро РСБУ 2023г: выручка 124,1 млрд руб (+11,6% г/г), чистая прибыль 21,47 млрд руб (рост в 2,17 раза)">
#           Юнипро РСБУ 2023г: выручка 124,1 млрд руб (+11,6% г/г), чистая прибыль 21,47 млрд руб (рост в 2,17 раза)
#          </a>
#         </div>
#        </h3>
#        <div style="margin: 0 -10px">
#         <a href="https://t.me/newssmartlab" target="_blank">
#          <img class="banner-img-tg" src="/templates/skin/smart-lab-x3/images/banners/news22.png?4579"/>
#         </a>
#        </div>
#        <h3 class="feed title bluid_30271">
#         <div class="rating">
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993104.php" title="Русолово получило разрешение Главгосэкспертизы на строительство подземного рудника на оловорудном месторождении Правоурмийское в Хабаровском крае">
#           Русолово получило разрешение Главгосэкспертизы на строительство подземного рудника на оловорудном месторождении Правоурмийское в Хабаровском крае
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_30271">
#         <div class="rating">
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993102.php" title='С 1 марта НПЗ "Лукойл нефтохим Бургас" окончательно потерял право на использование российской нефти для производства топлива'>
#           С 1 марта НПЗ "Лукойл нефтохим Бургас" окончательно потерял право на использование российской нефти для производства топлива
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_30271">
#         <div class="rating">
#          <div class="r">
#           +4
#          </div>
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993098.php" title="Послание Путина Федеральному Собранию - самый квалифицированный прогноз развития страны — Дмитрий Песков">
#           Послание Путина Федеральному Собранию - самый квалифицированный прогноз развития страны — Дмитрий Песков
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_45660">
#         <div class="rating">
#          <div class="c">
#           (1)
#          </div>
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993094.php" title="Бумаги Самолета интересны для покупки - Риком-Траст">
#           Бумаги Самолета интересны для покупки - Риком-Траст
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_57203">
#         <div class="rating">
#          <div class="r">
#           +4
#          </div>
#          <div class="c">
#           (2)
#          </div>
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993086.php" title="Йеллен не уверена, что страны G7 смогут в июне принять решение об изъятии активов РФ — RTRS">
#           Йеллен не уверена, что страны G7 смогут в июне принять решение об изъятии активов РФ — RTRS
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_57203">
#         <div class="rating">
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993081.php" title="Доля безналичных платежей в розничном обороте в 2023 году выросла на 5,3 п. п., до 83,4% — Набиуллина">
#           Доля безналичных платежей в розничном обороте в 2023 году выросла на 5,3 п. п., до 83,4% — Набиуллина
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_30271">
#         <div class="rating">
#          <div class="c">
#           (1) ★1
#          </div>
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993077.php" title="Полюс ожидает, что на фоне реализации Сухого Лога 2025-2027 годы окажутся пиковыми по capex — глава компании Алексей Востоков">
#           Полюс ожидает, что на фоне реализации Сухого Лога 2025-2027 годы окажутся пиковыми по capex — глава компании Алексей Востоков
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_57203">
#         <div class="rating">
#          <div class="c">
#           (4)
#          </div>
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993075.php" title="Управление «К» ФСБ начало проверку QIWI Банка, у которого на прошлой неделе отозвали лицензию">
#           Управление «К» ФСБ начало проверку QIWI Банка, у которого на прошлой неделе отозвали лицензию
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_30271">
#         <div class="rating">
#          <div class="c">
#           (1)
#          </div>
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993074.php" title='"Полюсу" нужно убедиться в достаточности денежного потока для возвращения к обсуждению дивидендов, нужна "разумная осмотрительность" — гендиректор'>
#           "Полюсу" нужно убедиться в достаточности денежного потока для возвращения к обсуждению дивидендов, нужна "разумная осмотрительность" — гендиректор
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_30271">
#         <div class="rating">
#          <div class="r">
#           +2
#          </div>
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993068.php" title="Набиуллина: Мы планируем ввести дифференциацию взносов банков в Фонд страхования вкладов">
#           Набиуллина: Мы планируем ввести дифференциацию взносов банков в Фонд страхования вкладов
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_57203">
#         <div class="rating">
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993067.php" title="С 1 марта дополнительно ужесточаем выдачу рискованной ипотеки и с середины 2024г будем применять в отношении ипотеки и макропруденциальные лимиты  — Набиуллина">
#           С 1 марта дополнительно ужесточаем выдачу рискованной ипотеки и с середины 2024г будем применять в отношении ипотеки и макропруденциальные лимиты  — Набиуллина
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_30271">
#         <div class="rating">
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993066.php" title='📉Акции Qiwi обновили исторический минимум пробив отметку в 200 руб: сегодня -5,5%, за месяц -60%. Шутники Cмартлаба соревнуются в юморе: "Кто не продал расписки Qiwi, тот поедет в Казахстан"'>
#           📉Акции Qiwi обновили исторический минимум пробив отметку в 200 руб: сегодня -5,5%, за месяц -60%. Шутники Cмартлаба соревнуются в юморе: "Кто не продал расписки Qiwi, тот поедет в Казахстан"
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_30271">
#         <div class="rating">
#         </div>
#         <div class="inside">
#          <span class="user">
#           01/03
#          </span>
#          <a href="/blog/993063.php" title="Новые антироссийские санкции США возможно сократят импорт энергетического угля в Индию из России — Reuters">
#           Новые антироссийские санкции США возможно сократят импорт энергетического угля в Индию из России — Reuters
#          </a>
#         </div>
#        </h3>
#        <h3 class="feed title bluid_57203">
#         <div class="rating">
#          <div class="r">
#           +4
#          </div>
# ...
#            Доходность активов 2024: акции, облигации, недвижимость, золото и серебро, депозиты
#           </a>
#          </div>
#          <div class="bluid_202915">
#           <span class="r">
#            ★4
#           </span>
#           <span class="c">
#            21
#           </span>
#           <a href="/blog/993276.php" title="30-летний пенсионер: Звонок из Сбера и Пчеловод.">
#            Звонок из Сбера и Пчеловод.
#           </a>
#          </div>
#          <div class="bluid_35585">
#           <span class="r">
#            ★4
#           </span>
#           <span class="c">
#            48
#           </span>
#           <a href="/blog/993154.php" title="Элвис cМартлабов: Траур и злоба: реакция главы Центробанка Набиулиной на послание президента">
#            Траур и злоба: реакция главы Центробанка Набиулиной на послание президента
#           </a>
#          </div>
#          <div class="bluid_73725">
#           <span class="r">
#            ★4
#           </span>
#           <span class="c">
#            34
#           </span>
#           <a href="/blog/993293.php" title="bohemian rhapsody: Практическое занятие  для начинающих опционщиков № 1. Покупка недельных опционов.">
#            Практическое занятие  для начинающих опционщиков № 1. Покупка недельных опционов.
#           </a>
#          </div>
#         </div>
#         <div>
#          <a href="/favtop/topic/24h/">
#           Полезные записи
#          </a>
#         </div>
#        </div>
#        <div class="tab">
#         <div class="trt">
#          <div class="bluid_16">
#           <span class="r">
#            +141
#           </span>
#           <span class="c">
#            22
#           </span>
#           <a href="/blog/993236.php" title="Тимофей Мартынов: Вестник нищеброда: самые дешевые способы внедриться в совет директоров компаний на Мосбирже">
#            Вестник нищеброда: самые дешевые способы внедриться в совет директоров компаний на Мосбирже
#           </a>
#          </div>
#          <div class="bluid_43010">
#           <span class="r">
#            +102
#           </span>
#           <span class="c">
#            17
#           </span>
#           <a href="/blog/993178.php" title='Дмитрий Овчинников: Сервис автоследования Comon. Разбираем данные. Что там "под капотом"?'>
#            Сервис автоследования Comon. Разбираем данные. Что там "под капотом"?
#           </a>
#          </div>
#          <div class="bluid_16">
#           <span class="r">
#            +98
#           </span>
#           <span class="c">
#            21
#           </span>
#           <a href="/blog/993240.php" title="Тимофей Мартынов: С утреца дал интервью Финаму с текущим вью по рынку">
#            С утреца дал интервью Финаму с текущим вью по рынку
#           </a>
#          </div>
#          <div class="bluid_35585">
#           <span class="r">
#            +88
#           </span>
#           <span class="c">
#            48
#           </span>
#           <a href="/blog/993154.php" title="Элвис cМартлабов: Траур и злоба: реакция главы Центробанка Набиулиной на послание президента">
#            Траур и злоба: реакция главы Центробанка Набиулиной на послание президента
#           </a>
#          </div>
#          <div class="bluid_101355">
#           <span class="r">
#            +79
#           </span>
#           <span class="c">
#            43
#           </span>
#           <a href="/blog/993207.php" title="GOLD: Рубль послан в 6-летний полет">
#            Рубль послан в 6-летний полет
#           </a>
#          </div>
#          <div class="bluid_216942">
#           <span class="r">
#            +67
#           </span>
#           <span class="c">
#            14
#           </span>
#           <a href="/blog/993168.php" title="Пунтусов Олег: Ошибка, которую я совершил 25 лет назад 🤪">
#            Ошибка, которую я совершил 25 лет назад 🤪
#           </a>
#          </div>
#          <div class="bluid_202915">
#           <span class="r">
#            +64
#           </span>
#           <span class="c">
#            21
#           </span>
#           <a href="/blog/993276.php" title="30-летний пенсионер: Звонок из Сбера и Пчеловод.">
#            Звонок из Сбера и Пчеловод.
#           </a>
#          </div>
#          <div class="bluid_45802">
#           <span class="r">
#            +57
#           </span>
#           <span class="c">
#            4
#           </span>
#           <a href="/blog/993264.php" title="Олег Кузьмичев: Ценовой потолок США на российскую нефть не работает - все покупают выше 60$ за баррель">
#            Ценовой потолок США на российскую нефть не работает - все покупают выше 60$ за баррель
#           </a>
#          </div>
#          <div class="bluid_180975">
#           <span class="r">
#            +55
#           </span>
#           <span class="c">
#            9
#           </span>
#           <a href="/blog/993314.php" title="igotosochi: Топ-10 дивидендных акций 2024 от аналитиков Финам">
#            Топ-10 дивидендных акций 2024 от аналитиков Финам
#           </a>
#          </div>
#          <div class="bluid_211644">
#           <span class="r">
#            +53
#           </span>
#           <span class="c">
#            0
#           </span>
#           <a href="/company/os_engine/blog/993349.php" title="OS_Engine_team: Индикатор OBV (On Balance Volume) и бесплатные роботы на нём.">
#            Индикатор OBV (On Balance Volume) и бесплатные роботы на нём.
#           </a>
#          </div>
#         </div>
#         <div>
#          <a href="/top/topic/24h/">
#           <h4>
#            Лучшие записи за 24 часа
#           </h4>
#          </a>
#         </div>
#        </div>
#        <div class="tab">
#         <h4>
#          самые обсуждаемые сегодня
#         </h4>
#         <div class="trt">
#          <div class="bluid_27689">
#           <span class="c">
#            141к
#           </span>
#           <a href="/blog/993305.php" title="RUH666: Итоги недели 29.02.2024. Послание Путина - анонс роста налогов? Курс доллара и нефть">
#            Итоги недели 29.02.2024. Послание Путина - анонс роста налогов? Курс доллара и нефть
#           </a>
#          </div>
#          <div class="bluid_142247">
#           <span class="c">
#            80к
#           </span>
#           <a href="/blog/993336.php" title="Лом: Как работает западная пропаганда.">
#            Как работает западная пропаганда.
#           </a>
#          </div>
#          <div class="bluid_29434">
#           <span class="c">
#            55к
#           </span>
#           <a href="/blog/993348.php" title="Маркиз Лафайет: Самые дорогие компании ЕС и как на них заработать.">
#            Самые дорогие компании ЕС и как на них заработать.
#           </a>
#          </div>
#          <div class="bluid_107773">
#           <span class="c">
#            41к
#           </span>
#           <a href="/blog/993321.php" title="Ухо спекулянта: Админы смартлаба куплены )">
#            Админы смартлаба куплены )
#           </a>
#          </div>
#          <div class="bluid_2958">
#           <span class="c">
#            29к
#           </span>
#           <a href="/blog/993335.php" title="Balboa: Дача - хозяйство  руководителя «Газпрома» Рема  Вяхирева , содержание и расходы">
#            Дача - хозяйство  руководителя «Газпрома» Рема  Вяхирева , содержание и расходы
#           </a>
#          </div>
#          <div class="bluid_208422">
#           <span class="c">
#            26к
#           </span>
#           <a href="/blog/993364.php" title="Fairman: Про негодяев на Смартлабе">
#            Про негодяев на Смартлабе
#           </a>
#          </div>
#          <div class="bluid_187297">
#           <span class="c">
#            22к
#           </span>
#           <a href="/blog/993359.php" title="Дмитрий Первый: Похождение по фьючам натгаза.">
#            Похождение по фьючам натгаза.
#           </a>
#          </div>
#          <div class="bluid_128879">
#           <span class="c">
#            19к
#           </span>
#           <a href="/blog/993328.php" title="Aprova3: Прекрасная Франция Будущего">
#            Прекрасная Франция Будущего
#           </a>
#          </div>
#          <div class="bluid_225663">
#           <span class="c">
#            16к
#           </span>
#           <a href="/blog/993346.php" title="treider: Тупик и выхода из него я не вижу!">
#            Тупик и выхода из него я не вижу!
#           </a>
#          </div>
#          <div class="bluid_66233">
#           <span class="c">
#            12к
#           </span>
#           <a href="/blog/993313.php" title="Какойто Неизвестных: Брокер АйТиИнвест">
#            Брокер АйТиИнвест
#           </a>
#          </div>
#         </div>
#         <div>
#          <a href="/top/topic/24h/by_comments/">
#           Самые комментируемые
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <!-- /Top24 -->
#      <!-- Contests -->
#      <!-- Contests -->
#      <div class="bbr__big sticky_block">
#       <!--AdFox START-->
#       <!--MarTi-->
#       <!--Площадка: smart-lab.ru / * / *-->
#       <!--Тип баннера: Side-->
#       <!--Расположение: 1-->
#       <div id="adfox_side1">
#       </div>
#       <script type="text/javascript">
#        window.yaContextCb.push(()=>{
# 				Ya.adfoxCode.create({
# 					ownerId: 254948,
# 					containerId: 'adfox_side1',
# 					params: {
# 						pp: 'noj',
# 						ps: 'cymb',
# 						p2: 'fvyf',
# 						puid1: ''
# 					},
# 				});
# 			});
#       </script>
#       <div class="banner">
#        <div class="banner_wrapper">
#         <a class="banner_button" href="/brokers-rating/" onclick="window.fz('track', 'Desktop SideBarButtonRating Click')" rel="nofollow" target="_blank">
#          Рейтинг брокеров
#         </a>
#        </div>
#        <div class="banner_wrapper">
#         <a class="banner_button" href="/stocks/" onclick="window.fz('track', 'Desktop SideBarButtonStocks Click')" rel="nofollow" target="_blank">
#          Купить акции
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <!-- /cached -->
#    </div>
#    <footer class="fooooooter" id="footer">
#     <div class="flinks">
#      <div>
#       <span class="flinks_heading">
#        Блоги
#       </span>
#       <a class="flinks_link" href="/allblog/">
#        Лента всех блогов
#       </a>
#       <a class="flinks_link" href="/favtop/">
#        Самые полезные
#       </a>
#       <a class="flinks_link" href="/top/topic/24h/by_comments/">
#        Самые комментируемые
#       </a>
#       <a class="flinks_link" href="/news/">
#        Новости
#       </a>
#       <a class="flinks_link" href="/blog/tradesignals/">
#        Торговые сигналы
#       </a>
#       <a class="flinks_link" href="/vopros/">
#        Ответы на вопросы
#       </a>
#       <a class="flinks_link" href="/blog/reviews/">
#        Книжные рецензии
#       </a>
#       <a class="flinks_link" href="/company/">
#        Корпоративные
#       </a>
#      </div>
#      <div>
#       <span class="flinks_heading">
#        Форумы
#       </span>
#       <a class="flinks_link" href="/forums/">
#        Лента всех форумов
#       </a>
#       <a class="flinks_link" href="/trading/">
#        Общие темы
#       </a>
#       <a class="flinks_link" href="/forum/">
#        Форум акций
#       </a>
#       <a class="flinks_link" href="/algotrading/">
#        Форум алготрейдинг
#       </a>
#       <a class="flinks_link" href="/options/">
#        Форум опционы
#       </a>
#       <a class="flinks_link" href="/crypto/">
#        Форум криптовалют
#       </a>
#       <a class="flinks_link" href="/forex/">
#        Форум Forex
#       </a>
#       <a class="flinks_link" href="/brokers-rating/">
#        Рейтинг брокеров
#       </a>
#      </div>
#      <div>
#       <span class="flinks_heading">
#        Акции
#       </span>
#       <a class="flinks_link" href="/q/map/">
#        Карта рынка
#       </a>
#       <a class="flinks_link" href="/q/shares/">
#        Котировки
#       </a>
#       <a class="flinks_link" href="/q/shares_fundamental/">
#        Фундаментальный анализ
#       </a>
#       <a class="flinks_link" href="/q/shares_fundamental/">
#        Отчеты компаний
#       </a>
#       <a class="flinks_link" href="/dividends/">
#        Дивиденды
#       </a>
#       <a class="flinks_link" href="/q/portfolio/">
#        Мой портфель
#       </a>
#       <a class="flinks_link" href="/forum/sectors/">
#        Все компании
#       </a>
#       <a class="flinks_link" href="/calendar/stocks/">
#        Календарь акций
#       </a>
#      </div>
#      <div>
#       <span class="flinks_heading">
#        Смартлаб
#       </span>
#       <a class="flinks_link" href="/page/values/">
#        Ценности смартлаба
#       </a>
#       <a class="flinks_link" href="/page/sitemap/">
#        Карта сайта
#       </a>
#       <a class="flinks_link" href="https://mediakit.smart-lab.ru/">
#        Реклама
#       </a>
#       <a class="flinks_link" href="/page/contact/">
#        Контакты
#       </a>
#       <a class="flinks_link" href="/page/jobs/">
#        Вакансии
#       </a>
#       <a class="flinks_link" href="/blog/mytrading/5161.php">
#        Правила
#       </a>
#       <a class="flinks_link" href="/page/help/">
#        Помощь
#       </a>
#       <a class="flinks_link" href="/trading/%D0%97%D0%B0%D0%B4%D0%B0%D0%B9%20%D0%B2%D0%BE%D0%BF%D1%80%D0%BE%D1%81%20%D0%A2%D0%B8%D0%BC%D0%BE%D1%84%D0%B5%D1%8E%20%D0%9C%D0%B0%D1%80%D1%82%D1%8B%D0%BD%D0%BE%D0%B2%D1%83">
#        Обратная связь
#       </a>
#      </div>
#     </div>
#     <div class="footer__bottom">
#      <div class="footer__moex">
#       <a class="i" href="https://www.moex.com/" target="_blank">
#        <img src="/uploads/2021/images/01/15/47/2021/12/17/avatar_c6f6bc_140x140.webp?4579"/>
#       </a>
#       <div class="footer__moex-text">
#        <a href="https://www.moex.com/?utm_source=smartlab&amp;erid=LdtCKJfQi" target="_blank">
#         Московская Биржа
#        </a>
#        является спонсором ресурса smart-lab.ru
#       </div>
#      </div>
#      <div class="footer__counter">
#       <a class="footer__counter-link" href="//www.liveinternet.ru/click" id="footer__counter" target="_blank">
#        <img alt="" height="31" id="licnt497C" src="..." style="border:0" title="LiveInternet: показано число просмотров за 24 часа, посетителей за 24 часа и за сегодня" width="88"/>
#       </a>
#       <script>
#        (function(d,s){d.getElementById("licnt497C").src=
# 			"//counter.yadro.ru/hit?t18.3;r"+escape(d.referrer)+
# 			((typeof(s)=="undefined")?"":";s"+s.width+"*"+s.height+"*"+
# 			(s.colorDepth?s.colorDepth:s.pixelDepth))+";u"+escape(d.URL)+
# 			";h"+escape(d.title.substring(0,150))+";"+Math.random()})
# 			(document,screen)
#       </script>
#      </div>
#     </div>
#    </footer>
#    <!--LiveInternet counter-->
#    <div class="liveinternet_wrapper">
#     <a href="//www.liveinternet.ru/click" target="_blank">
#      <img alt="" height="31" id="licnt497C" src="..." style="border:0" title="LiveInternet: показано число просмотров за 24 часа, посетителей за 24 часа и за сегодня" width="88"/>
#     </a>
#     <script>
#      (function(d,s){d.getElementById("licnt497C").src=
# 	"//counter.yadro.ru/hit?t18.3;r"+escape(d.referrer)+
# 	((typeof(s)=="undefined")?"":";s"+s.width+"*"+s.height+"*"+
# 	(s.colorDepth?s.colorDepth:s.pixelDepth))+";u"+escape(d.URL)+
# 	";h"+escape(d.title.substring(0,150))+";"+Math.random()})
# 	(document,screen)
#     </script>
#    </div>
#    <!--/LiveInternet-->
#    <!-- Yandex.Metrika counter -->
#    <script type="text/javascript">
#     (function (d, w, c) {
# (w[c] = w[c] || []).push(function() {
# try {
# w.yaCounter32877692 = new Ya.Metrika({
# id:32877692,
# clickmap:true,
# trackLinks:true,
# accurateTrackBounce:true
# });
# } catch(e) { }
# });
#
# var n = d.getElementsByTagName("script")[0],
# s = d.createElement("script"),
# f = function () { n.parentNode.insertBefore(s, n); };
# s.type = "text/javascript";
# s.async = true;
# s.src = "https://mc.yandex.ru/metrika/watch.js";
#
# if (w.opera == "[object Opera]") {
# d.addEventListener("DOMContentLoaded", f, false);
# } else { f(); }
# })(document, window, "yandex_metrika_callbacks");
#    </script>
#    <noscript>
#     <div>
#      <img alt="" src="https://mc.yandex.ru/watch/32877692" style="position:absolute; left:-9999px;"/>
#     </div>
#    </noscript>
#    <!-- /Yandex.Metrika counter -->
#    <!-- poll_dialog_block -->
#    <div class="toolbar">
#     <span class="scrollUp" title="Наверх">
#      UP
#     </span>
#     <span class="scrollDown" title="Вниз">
#      DONW
#     </span>
#    </div>
#    <a class="transfer-btn transfer-btn--to-new" href="https://smart-lab.ru/mobile/allnews/">
#     Новый дизайн
#    </a>
#   </div>
#  </body>
# </html>

# %%
print(mysoup.title)
# Out:
# <title>Новости компаний и новости по акциям</title>
